# %%
#Should decision tree regression be used to predict how much a home costs

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
trainingDf = pd.read_csv('train.csv')
testDf = pd.read_csv('test.csv')

# %%
sns.scatterplot(data=trainingDf, x='budget', y='revenue')
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
stdBudget = np.std(trainingDf['budget'])
stdRevenue = np.std(trainingDf['revenue'])
corr = trainingDf['revenue'].corr(trainingDf['budget'])

m = (stdRevenue / stdBudget) * corr

m
# Out:
# 2.7968648808561474
